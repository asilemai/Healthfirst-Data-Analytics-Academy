# %% [markdown]
# # Odd or Even Python Project
#
# This program asks the user to enter a number and determines if it is odd or even.
# It also checks if the number is a multiple of 4.
# Finally, it asks for two numbers and determines if one divides evenly into the other.

# %%
# ask the user for a number
num = int(input("Enter a number: "))

# check if number is even or odd
if num % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")

# check if it is a multiple of 4
if num % 4 == 0:
    print("The number is also a multiple of 4")

# ask the user for two numbers
num2 = int(input("Enter a number to check: "))
check = int(input("Enter a number to divide by: "))

# check if it divides evenly
if num2 % check == 0:
    print("It divides evenly")
else:
    print("It does not divide evenly")
# Out:
# Enter a number: 12
# The number is even
# The number is also a multiple of 4
# Enter a number to check: 20
# Enter a number to divide by: 5
# It divides evenly

# %% [markdown]
# ## Conclusion
#
# In this test, the program checked the number 12 and determined that it is even and also a multiple of 4. The program then checked if 20 could be divided evenly by 5 and confirmed that it does divide evenly. This shows that the program works correctly for identifying even and odd numbers, detecting multiples of 4, and checking if one number divides evenly into another.
